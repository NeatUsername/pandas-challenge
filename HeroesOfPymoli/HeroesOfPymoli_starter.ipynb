# %% [markdown]
# ### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import pandas as pd

# File to Load (Remember to Change These)
file_to_load = "Resources/purchase_data.csv"

# Read Purchasing File and store into Pandas data frame
purchase_data_df = pd.read_csv(file_to_load)

## Checking import of data worked and understanding data structure
purchase_data_df.head()
# Out:
#    Purchase ID             SN  Age Gender  Item ID  \
# 0            0        Lisim78   20   Male      108
# 1            1    Lisovynya38   40   Male      143
# 2            2     Ithergue48   24   Male       92
# 3            3  Chamassasya86   24   Male      100
# 4            4      Iskosia90   23   Male      131
#
#                                    Item Name  Price
# 0  Extraction, Quickblade Of Trembling Hands   3.53
# 1                          Frenzied Scimitar   1.56
# 2                               Final Critic   4.88
# 3                                Blindscythe   3.27
# 4                                       Fury   1.44

# %% [markdown]
# ## Player Count

# %% [markdown]
# * Display the total number of players

# %%
## Option 1:  Throw selected column data into new dataframe and use the .count method
#player_count_df = purchase_data_df["SN"]
#player_count_df.count()

# %%
## Option 2:  Use existing dataframe and utilize the .describe method.  Drawback:  lists additional
# unnecessary information at the same time.  This is also a gross count, meaning duplicate purchases
# by the same user will inflate the number.

#purchase_data_df.describe()

# %%
## Option 3:  Use the .nunique method to count only unique values.
#purchase_data_df.nunique()

# %%
## Option 3 continued:  The above result is a great illustration of commentary in option 2.
# The unique accounts of "Purchase ID" and "SN" differ significantly - So our final solution here 
# will be to contrain our query to the "SN" column. [ Cite your sources:  Found this solution
# via the amazing Stack Overflow, 
# https://stackoverflow.com/questions/15411158/pandas-countdistinct-equivalent ].

## For presentation purposes I'm adding a descriptive statement alongside the result.
players = purchase_data_df["SN"].nunique()

print(f"Total Player Count:  {players}")
# Out:
# Total Player Count:  576

# %% [markdown]
# ## Purchasing Analysis (Total)
#
# * Run basic calculations to obtain number of unique items, average price, etc.
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
## Unique Item Count task.  Using the .value_counts method to pull out uniques and then the
# len function to count the objects in that new list.

unique_item_count = len(purchase_data_df["Item ID"].value_counts())

## Average Purchase Price task.  Straight-forward, using .mean method.
avg_purch_price = purchase_data_df["Price"].mean()

## Total Purchases Task.  Using .count method.
total_purch = purchase_data_df["Purchase ID"].count()

## Total Revenue Task.  Using .sum method.
total_revenue = purchase_data_df["Price"].sum()

## Creating new summary dataframe to combine the above calculations
# using the pd.DataFrame method going to smash to gether the calcs above.  Is this technically
# a dictionary since we're using the format of Key:value pairs?
purchase_analysis_df = pd.DataFrame({"Number of Unique Items": [unique_item_count],
                                  "Avg Purchase Price": [avg_purch_price],
                                  "Total Purchases": [total_purch],
                                  "Total Revenue": [total_revenue]
                                 })

## Gonna go for that sweet optional bonus and format the columns via mapping method
purchase_analysis_df["Avg Purchase Price"] = purchase_analysis_df["Avg Purchase Price"].map("${:.2f}".format)
purchase_analysis_df["Total Revenue"] = purchase_analysis_df["Total Revenue"].map("${:,.2f}".format)
purchase_analysis_df
# Out:
#    Number of Unique Items Avg Purchase Price  Total Purchases Total Revenue
# 0                     179              $3.05              780     $2,379.77

# %% [markdown]
# ## Gender Demographics

# %% [markdown]
# * Percentage and Count of Male Players
#
#
# * Percentage and Count of Female Players
#
#
# * Percentage and Count of Other / Non-Disclosed

# %%
# Use Groupby method for the gender analysis
demo_gender_detail_df = purchase_data_df.groupby(["Gender"])
# Calculate number of distinct users
demo_gender_count = demo_gender_detail_df["SN"].nunique()
# Calculate percentage
demo_gender_percent = demo_gender_count / players
demo_gender_percent = demo_gender_percent.map("{:.2%}".format)
#combine into new dataframe vai pd.DataFrame method
demo_gender_summary = pd.DataFrame({"Gender Count": demo_gender_count,
                                   "Percent": demo_gender_percent})
demo_gender_summary.sort_values(["Gender Count"], ascending = False)
# Out:
#                        Gender Count Percent
# Gender
# Male                            484  84.03%
# Female                           81  14.06%
# Other / Non-Disclosed            11   1.91%

# %% [markdown]
# ## Purchasing Analysis (Gender)

# %% [markdown]
# * Run basic calculations to obtain purchase count, avg. purchase price, avg. purchase total per person etc. by gender
#
#
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
#Count calc
purch_gender_purch_count = demo_gender_detail_df["Purchase ID"].count()

#purch avg calc
purch_gender_purch_avg = demo_gender_detail_df["Price"].mean()

#Total Purch calc
purch_gender_purch_tot = demo_gender_detail_df["Price"].sum()

#Avg Total Purch Calc
purch_gender_tot_avg = purch_gender_purch_tot / demo_gender_count

purch_gender_summary = pd.DataFrame({"Purchase Count": purch_gender_purch_count,
                                    "Avg Purchase Price": purch_gender_purch_avg,
                                    "Total Purchase Amt": purch_gender_purch_tot,
                                    "Avg Total Purchase": purch_gender_tot_avg })

purch_gender_summary.index.name = "Gender"

purch_gender_summary["Avg Purchase Price"] = purch_gender_summary["Avg Purchase Price"].map("${:,.2f}".format)
purch_gender_summary["Total Purchase Amt"] = purch_gender_summary["Total Purchase Amt"].map("${:,.2f}".format)
purch_gender_summary["Avg Total Purchase"] = purch_gender_summary["Avg Total Purchase"].map("${:,.2f}".format)
purch_gender_summary
# Out:
#                        Purchase Count Avg Purchase Price Total Purchase Amt  \
# Gender
# Female                            113              $3.20            $361.94
# Male                              652              $3.02          $1,967.64
# Other / Non-Disclosed              15              $3.35             $50.19
#
#                       Avg Total Purchase
# Gender
# Female                             $4.47
# Male                               $4.07
# Other / Non-Disclosed              $4.56

# %% [markdown]
# ## Age Demographics

# %% [markdown]
# * Establish bins for ages
#
#
# * Categorize the existing players using the age bins. Hint: use pd.cut()
#
#
# * Calculate the numbers and percentages by age group
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: round the percentage column to two decimal points
#
#
# * Display Age Demographics Table

# %%
#Creating bins for the break-outs
bin_ages = [0, 9.9, 14.9, 19.9, 24.9, 29.9, 34.9, 39.9, 999]
bin_ages_titles = ["<10", "10-14","15-19","20-24","25-29","30-34","35-39","40+"]

#New column for the age summary
demo_age_df["Age Groups"] = pd.cut(purchase_data_df["Age"], bin_ages, labels = bin_ages_titles)

demo_age_totals = demo_age_df["Age Groups"].value_counts()
demo_age_perc = demo_age_totals / players

demo_age_summary = pd.DataFrame({"Total Purchase By Age": demo_age_totals,
                                 "Percentage": demo_age_perc})
demo_age_summary["Percentage"] =  demo_age_summary["Percentage"].map("{:.2%}".format)


demo_age_summary.sort_index()
# Out:
# C:\Users\simon\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#        Total Purchase By Age Percentage
# <10                       17      2.95%
# 10-14                     22      3.82%
# 15-19                    107     18.58%
# 20-24                    258     44.79%
# 25-29                     77     13.37%
# 30-34                     52      9.03%
# 35-39                     31      5.38%
# 40+                       12      2.08%

# %% [markdown]
# ## Purchasing Analysis (Age)

# %% [markdown]
# * Bin the purchase_data data frame by age
#
#
# * Run basic calculations to obtain purchase count, avg. purchase price, avg. purchase total per person etc. in the table below
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
purchase_data_df["Age Ranges"] = pd.cut(purchase_data_df["Age"], bin_ages, labels = bin_ages_titles)

age_purch_group = purchase_data_df.groupby("Age Ranges")

age_purch_count = age_purch_group["Purchase ID"].count()
age_avg_prc = age_purch_group["Price"].mean()
age_tot_val = age_purch_group["Price"].sum()
age_avg_per_person = age_tot_val / demo_age_totals
age_summary_df = pd.DataFrame({"Purchase Count": age_purch_count,
                                "AVG Purchase Price": age_avg_prc,
                                "Total Purchases": age_tot_val,
                                "AVG Per-Person Total": age_avg_per_person })
age_summary_df
# Out:
#        Purchase Count  AVG Purchase Price  Total Purchases  \
# <10                23            3.353478            77.13
# 10-14              28            2.956429            82.78
# 15-19             136            3.035956           412.89
# 20-24             365            3.052219          1114.06
# 25-29             101            2.900990           293.00
# 30-34              73            2.931507           214.00
# 35-39              41            3.601707           147.67
# 40+                13            2.941538            38.24
#
#        AVG Per-Person Total
# <10                4.537059
# 10-14              3.762727
# 15-19              3.858785
# 20-24              4.318062
# 25-29              3.805195
# 30-34              4.115385
# 35-39              4.763548
# 40+                3.186667

# %% [markdown]
# ## Top Spenders

# %% [markdown]
# * Run basic calculations to obtain the results in the table below
#
#
# * Create a summary data frame to hold the results
#
#
# * Sort the total purchase value column in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the summary data frame

# %%
#multiple transactions per user, so groupby on SN is necessary
top_spend_group = purchase_data_df.groupby(["SN"])
top_spend_pur_cnt = top_spend_group.count()
#avg purch price
top_spend_pur_avg = top_spend_group["Price"].mean()
top_spend_pur_tot = top_spend_group["Price"].sum()
top_spend_summary_df = pd.DataFrame({"Purchase Count": top_spend_pur_cnt,
                                     "AVG Purchase Price": top_spend_pur_avg,
                                     "Total Purchases": top_spend_pur_tot
                                    })

top_spend_summary_df = top_spend_summary_df.sort_values("Total PUrchases", ascending = False).head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\internals\managers.py in create_block_manager_from_arrays(arrays, names, axes)
#    1692         blocks = form_blocks(arrays, names, axes)
# -> 1693         mgr = BlockManager(blocks, axes)
#    1694         mgr._consolidate_inplace()
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\internals\managers.py in __init__(self, blocks, axes, do_integrity_check)
#     148         if do_integrity_check:
# --> 149             self._verify_integrity()
#     150
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\internals\managers.py in _verify_integrity(self)
#     328             if block.shape[1:] != mgr_shape[1:]:
# --> 329                 raise construction_error(tot_items, block.shape[1:], self.axes)
#     330         if len(self.items) != tot_items:
#
# ValueError: Shape of passed values is (7, 3), indices imply (576, 3)
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-140-ca6f51f6c3bb> in <module>
#       7 top_spend_summary_df = pd.DataFrame({"Purchase Count": top_spend_pur_cnt,
#       8                                      "AVG Purchase Price": top_spend_pur_avg,
# ----> 9                                      "Total Purchases": top_spend_pur_tot
#      10                                     })
#      11
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     466
#     467         elif isinstance(data, dict):
# --> 468             mgr = init_dict(data, index, columns, dtype=dtype)
#     469         elif isinstance(data, ma.MaskedArray):
#     470             import numpy.ma.mrecords as mrecords
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\internals\construction.py in init_dict(data, index, columns, dtype)
#     281             arr if not is_datetime64tz_dtype(arr) else arr.copy() for arr in arrays
#     282         ]
# --> 283     return arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     284
#     285
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\internals\construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype, verify_integrity)
#      91     axes = [columns, index]
#      92
# ---> 93     return create_block_manager_from_arrays(arrays, arr_names, axes)
#      94
#      95
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\internals\managers.py in create_block_manager_from_arrays(arrays, names, axes)
#    1695         return mgr
#    1696     except ValueError as e:
# -> 1697         raise construction_error(len(arrays), arrays[0].shape, axes, e)
#    1698
#    1699
#
# ValueError: Shape of passed values is (7, 3), indices imply (576, 3)

# %% [markdown]
# ## Most Popular Items

# %% [markdown]
# * Retrieve the Item ID, Item Name, and Item Price columns
#
#
# * Group by Item ID and Item Name. Perform calculations to obtain purchase count, average item price, and total purchase value
#
#
# * Create a summary data frame to hold the results
#
#
# * Sort the purchase count column in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the summary data frame

# %%
# Out:
#                                                      Purchase Count  \
# Item ID Item Name
# 92      Final Critic                                             13
# 178     Oathbreaker, Last Hope of the Breaking Storm             12
# 145     Fiery Glass Crusader                                      9
# 132     Persuasion                                                9
# 108     Extraction, Quickblade Of Trembling Hands                 9
#
#                                                      Item Price  \
# Item ID Item Name
# 92      Final Critic                                      $4.61
# 178     Oathbreaker, Last Hope of the Breaking Storm      $4.23
# 145     Fiery Glass Crusader                              $4.58
# 132     Persuasion                                        $3.22
# 108     Extraction, Quickblade Of Trembling Hands         $3.53
#
#                                                      Total Purchase Value
# Item ID Item Name
# 92      Final Critic                                               $59.99
# 178     Oathbreaker, Last Hope of the Breaking Storm               $50.76
# 145     Fiery Glass Crusader                                       $41.22
# 132     Persuasion                                                 $28.99
# 108     Extraction, Quickblade Of Trembling Hands                  $31.77

# %% [markdown]
# ## Most Profitable Items

# %% [markdown]
# * Sort the above table by total purchase value in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the data frame

# %%
# Out:
#                                                      Purchase Count  \
# Item ID Item Name
# 92      Final Critic                                             13
# 178     Oathbreaker, Last Hope of the Breaking Storm             12
# 82      Nirvana                                                   9
# 145     Fiery Glass Crusader                                      9
# 103     Singed Scalpel                                            8
#
#                                                      Item Price  \
# Item ID Item Name
# 92      Final Critic                                      $4.61
# 178     Oathbreaker, Last Hope of the Breaking Storm      $4.23
# 82      Nirvana                                           $4.90
# 145     Fiery Glass Crusader                              $4.58
# 103     Singed Scalpel                                    $4.35
#
#                                                      Total Purchase Value
# Item ID Item Name
# 92      Final Critic                                               $59.99
# 178     Oathbreaker, Last Hope of the Breaking Storm               $50.76
# 82      Nirvana                                                    $44.10
# 145     Fiery Glass Crusader                                       $41.22
# 103     Singed Scalpel                                             $34.80
